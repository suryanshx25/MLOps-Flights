# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("Data_Train.xlsx")

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
plt.figure(figsize=(15,7))
plt.title("Null values in each col")
sns.heatmap(df.isnull())
plt.xlabel("Columns")
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 220

# %%
df[df.duplicated()].sort_values(["Airline", "Date_of_Journey", "Source", "Destination"])
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 9848    Air India      01/03/2019  Banglore   New Delhi
# 8168    Air India      03/03/2019  Banglore   New Delhi
# 9913    Air India       1/04/2019   Kolkata    Banglore
# 5042    Air India       1/05/2019   Kolkata    Banglore
# 6377    Air India       1/05/2019   Kolkata    Banglore
# ...           ...             ...       ...         ...
# 9216  Jet Airways       9/06/2019     Delhi      Cochin
# 7502     SpiceJet      03/03/2019  Banglore   New Delhi
# 2870     SpiceJet      24/03/2019  Banglore   New Delhi
# 3711     SpiceJet      24/03/2019  Banglore   New Delhi
# 5470      Vistara      24/03/2019  Banglore   New Delhi
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 9848  BLR → BOM → AMD → DEL    08:50  23:55 02 Mar   39h 5m     2 stops
# 8168              BLR → DEL    21:10         23:55   2h 45m    non-stop
# 9913  CCU → DEL → COK → BLR    10:00  01:20 02 Apr  15h 20m     2 stops
# 5042  CCU → DEL → COK → BLR    10:00  13:45 02 May  27h 45m     2 stops
# 6377  CCU → DEL → COK → BLR    10:00  13:45 02 May  27h 45m     2 stops
# ...                     ...      ...           ...      ...         ...
# 9216  DEL → IDR → BOM → COK    05:30  04:25 10 Jun  22h 55m     2 stops
# 7502              BLR → DEL    20:30         23:20   2h 50m    non-stop
# 2870              BLR → DEL    05:45         08:35   2h 50m    non-stop
# 3711              BLR → DEL    20:30         23:20   2h 50m    non-stop
# 5470              BLR → DEL    11:30         14:10   2h 40m    non-stop
#
#                    Additional_Info  Price
# 9848                       No info  17135
# 8168                       No info   7591
# 9913                       No info  10408
# 5042                       No info  15164
# 6377                       No info  15164
# ...                            ...    ...
# 9216                       No info  13292
# 7502                       No info   6860
# 2870  No check-in baggage included   4273
# 3711  No check-in baggage included   3873
# 5470                       No info   5403
#
# [220 rows x 11 columns]

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df['Date_of_Journey']=pd.to_datetime(df['Date_of_Journey'],format='%d/%m/%Y')

# %%
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
df.describe()
# Out:
#                      Date_of_Journey         Price
# count                          10682  10682.000000
# mean   2019-05-04 19:56:32.398427392   9087.214567
# min              2019-03-01 00:00:00   1759.000000
# 25%              2019-03-27 00:00:00   5277.000000
# 50%              2019-05-15 00:00:00   8372.000000
# 75%              2019-06-06 00:00:00  12373.000000
# max              2019-06-27 00:00:00  79512.000000
# std                              NaN   4611.548810

# %%
df.describe(include='object')
# Out:
#             Airline Source Destination            Route Dep_Time Arrival_Time  \
# count         10682  10682       10682            10682    10682        10682
# unique           12      5           6              128      222         1343
# top     Jet Airways  Delhi      Cochin  DEL → BOM → COK    18:55        19:00
# freq           3849   4536        4536             2376      233          423
#
#        Duration Total_Stops Additional_Info
# count     10682       10682           10682
# unique      368           5              10
# top      2h 50m      1 stop         No info
# freq        550        5625            8344

# %%
for i in df.describe(include='object').columns:
    # Columns
    print(f"Unique Values in {i}")
    
    # Show Unique Values
    print(df[i].unique())
    
    
    # Total Unique Values
    print(f"Total Unique values are:  {df[i].nunique()}")
    
    print("-*"*50)
    print()
# Out:
# Unique Values in Airline
# ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']
# Total Unique values are:  12
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Source
# ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']
# Total Unique values are:  5
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Destination
# ['New Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Delhi' 'Hyderabad']
# Total Unique values are:  6
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Route
# ['BLR → DEL' 'CCU → IXR → BBI → BLR' 'DEL → LKO → BOM → COK'
#  'CCU → NAG → BLR' 'BLR → NAG → DEL' 'CCU → BLR' 'BLR → BOM → DEL'
#  'DEL → BOM → COK' 'DEL → BLR → COK' 'MAA → CCU' 'CCU → BOM → BLR'
#  'DEL → AMD → BOM → COK' 'DEL → PNQ → COK' 'DEL → CCU → BOM → COK'
#  'BLR → COK → DEL' 'DEL → IDR → BOM → COK' 'DEL → LKO → COK'
#  'CCU → GAU → DEL → BLR' 'DEL → NAG → BOM → COK' 'CCU → MAA → BLR'
#  'DEL → HYD → COK' 'CCU → HYD → BLR' 'DEL → COK' 'CCU → DEL → BLR'
#  'BLR → BOM → AMD → DEL' 'BOM → DEL → HYD' 'DEL → MAA → COK' 'BOM → HYD'
#  'DEL → BHO → BOM → COK' 'DEL → JAI → BOM → COK' 'DEL → ATQ → BOM → COK'
#  'DEL → JDH → BOM → COK' 'CCU → BBI → BOM → BLR' 'BLR → MAA → DEL'
#  'DEL → GOI → BOM → COK' 'DEL → BDQ → BOM → COK' 'CCU → JAI → BOM → BLR'
#  'CCU → BBI → BLR' 'BLR → HYD → DEL' 'DEL → TRV → COK'
#  'CCU → IXR → DEL → BLR' 'DEL → IXU → BOM → COK' 'CCU → IXB → BLR'
#  'BLR → BOM → JDH → DEL' 'DEL → UDR → BOM → COK' 'DEL → HYD → MAA → COK'
#  'CCU → BOM → COK → BLR' 'BLR → CCU → DEL' 'CCU → BOM → GOI → BLR'
#  'DEL → RPR → NAG → BOM → COK' 'DEL → HYD → BOM → COK'
#  'CCU → DEL → AMD → BLR' 'CCU → PNQ → BLR' 'BLR → CCU → GAU → DEL'
#  'CCU → DEL → COK → BLR' 'BLR → PNQ → DEL' 'BOM → JDH → DEL → HYD'
#  'BLR → BOM → BHO → DEL' 'DEL → AMD → COK' 'BLR → LKO → DEL'
#  'CCU → GAU → BLR' 'BOM → GOI → HYD' 'CCU → BOM → AMD → BLR'
#  'CCU → BBI → IXR → DEL → BLR' 'DEL → DED → BOM → COK'
#  'DEL → MAA → BOM → COK' 'BLR → AMD → DEL' 'BLR → VGA → DEL'
#  'CCU → JAI → DEL → BLR' 'CCU → AMD → BLR' 'CCU → VNS → DEL → BLR'
#  'BLR → BOM → IDR → DEL' 'BLR → BBI → DEL' 'BLR → GOI → DEL'
#  'BOM → AMD → ISK → HYD' 'BOM → DED → DEL → HYD' 'DEL → IXC → BOM → COK'
#  'CCU → PAT → BLR' 'BLR → CCU → BBI → DEL' 'CCU → BBI → HYD → BLR'
#  'BLR → BOM → NAG → DEL' 'BLR → CCU → BBI → HYD → DEL' 'BLR → GAU → DEL'
#  'BOM → BHO → DEL → HYD' 'BOM → JLR → HYD' 'BLR → HYD → VGA → DEL'
#  'CCU → KNU → BLR' 'CCU → BOM → PNQ → BLR' 'DEL → BBI → COK'
#  'BLR → VGA → HYD → DEL' 'BOM → JDH → JAI → DEL → HYD'
#  'DEL → GWL → IDR → BOM → COK' 'CCU → RPR → HYD → BLR' 'CCU → VTZ → BLR'
#  'CCU → DEL → VGA → BLR' 'BLR → BOM → IDR → GWL → DEL'
#  'CCU → DEL → COK → TRV → BLR' 'BOM → COK → MAA → HYD' 'BOM → NDC → HYD'
#  'BLR → BDQ → DEL' 'CCU → BOM → TRV → BLR' 'CCU → BOM → HBX → BLR'
#  'BOM → BDQ → DEL → HYD' 'BOM → CCU → HYD' 'BLR → TRV → COK → DEL'
#  'BLR → IDR → DEL' 'CCU → IXZ → MAA → BLR' 'CCU → GAU → IMF → DEL → BLR'
#  'BOM → GOI → PNQ → HYD' 'BOM → BLR → CCU → BBI → HYD' 'BOM → MAA → HYD'
#  'BLR → BOM → UDR → DEL' 'BOM → UDR → DEL → HYD' 'BLR → VGA → VTZ → DEL'
#  'BLR → HBX → BOM → BHO → DEL' 'CCU → IXA → BLR' 'BOM → RPR → VTZ → HYD'
#  'BLR → HBX → BOM → AMD → DEL' 'BOM → IDR → DEL → HYD' 'BOM → BLR → HYD'
#  'BLR → STV → DEL' 'CCU → IXB → DEL → BLR' 'BOM → JAI → DEL → HYD'
#  'BOM → VNS → DEL → HYD' 'BLR → HBX → BOM → NAG → DEL'
#  'BLR → BOM → IXC → DEL' 'BLR → CCU → BBI → HYD → VGA → DEL'
#  'BOM → BBI → HYD']
# Total Unique values are:  128
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Dep_Time
# ['22:20' '05:50' '09:25' '18:05' '16:50' '09:00' '18:55' '08:00' '08:55'
#  '11:25' '09:45' '20:20' '11:40' '21:10' '17:15' '16:40' '08:45' '14:00'
#  '20:15' '16:00' '14:10' '22:00' '04:00' '21:25' '21:50' '07:00' '07:05'
#  '09:50' '14:35' '10:35' '15:05' '14:15' '06:45' '20:55' '11:10' '05:45'
#  '19:00' '23:05' '11:00' '09:35' '21:15' '23:55' '19:45' '08:50' '15:40'
#  '06:05' '15:00' '13:55' '05:55' '13:20' '05:05' '06:25' '17:30' '08:20'
#  '19:55' '06:30' '14:05' '02:00' '09:40' '08:25' '20:25' '13:15' '02:15'
#  '16:55' '20:45' '05:15' '19:50' '20:00' '06:10' '19:30' '04:45' '12:55'
#  '18:15' '17:20' '15:25' '23:00' '12:00' '14:45' '11:50' '11:30' '14:40'
#  '19:10' '06:00' '23:30' '07:35' '13:05' '12:30' '15:10' '12:50' '18:25'
#  '16:30' '00:40' '06:50' '13:00' '19:15' '01:30' '17:00' '10:00' '19:35'
#  '15:30' '12:10' '16:10' '20:35' '22:25' '21:05' '05:35' '05:10' '06:40'
#  '15:15' '00:30' '08:30' '07:10' '05:30' '14:25' '05:25' '10:20' '17:45'
#  '13:10' '22:10' '04:55' '17:50' '21:20' '06:20' '15:55' '20:30' '17:25'
#  '09:30' '07:30' '02:35' '10:55' '17:10' '09:10' '18:45' '15:20' '22:50'
#  '14:55' '14:20' '13:25' '22:15' '11:05' '16:15' '20:10' '06:55' '19:05'
#  '07:55' '07:45' '10:10' '08:15' '11:35' '21:00' '17:55' '16:45' '18:20'
#  '03:50' '08:35' '19:20' '20:05' '17:40' '04:40' '17:35' '09:55' '05:00'
#  '18:00' '02:55' '20:40' '22:55' '22:40' '21:30' '08:10' '17:05' '07:25'
#  '15:45' '09:15' '15:50' '11:45' '22:05' '18:35' '00:25' '19:40' '20:50'
#  '22:45' '10:30' '23:25' '11:55' '10:45' '11:15' '12:20' '14:30' '07:15'
#  '01:35' '18:40' '09:20' '21:55' '13:50' '01:40' '00:20' '04:15' '13:45'
#  '18:30' '06:15' '02:05' '12:15' '13:30' '06:35' '10:05' '08:40' '03:05'
#  '21:35' '16:35' '02:30' '16:25' '05:40' '15:35' '13:40' '07:20' '04:50'
#  '12:45' '10:25' '12:05' '11:20' '21:40' '03:00']
# Total Unique values are:  222
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Arrival_Time
# ['01:10 22 Mar' '13:15' '04:25 10 Jun' ... '06:50 10 Mar' '00:05 19 Mar'
#  '21:20 13 Mar']
# Total Unique values are:  1343
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Duration
# ['2h 50m' '7h 25m' '19h' '5h 25m' '4h 45m' '2h 25m' '15h 30m' '21h 5m'
#  '25h 30m' '7h 50m' '13h 15m' '2h 35m' '2h 15m' '12h 10m' '26h 35m'
#  '4h 30m' '22h 35m' '23h' '20h 35m' '5h 10m' '15h 20m' '2h 55m' '13h 20m'
#  '15h 10m' '5h 45m' '5h 55m' '13h 25m' '22h' '5h 30m' '10h 25m' '5h 15m'
#  '2h 30m' '6h 15m' '11h 55m' '11h 5m' '8h 30m' '22h 5m' '2h 45m' '12h'
#  '16h 5m' '19h 55m' '3h 15m' '25h 20m' '3h' '16h 15m' '15h 5m' '6h 30m'
#  '25h 5m' '12h 25m' '27h 20m' '10h 15m' '10h 30m' '1h 30m' '1h 25m'
#  '26h 30m' '7h 20m' '13h 30m' '5h' '19h 5m' '14h 50m' '2h 40m' '22h 10m'
#  '9h 35m' '10h' '21h 20m' '18h 45m' '12h 20m' '18h' '9h 15m' '17h 30m'
#  '16h 35m' '12h 15m' '7h 30m' '24h' '8h 55m' '7h 10m' '14h 30m' '30h 20m'
#  '15h' '12h 45m' '10h 10m' '15h 25m' '14h 5m' '20h 15m' '23h 10m'
#  '18h 10m' '16h' '2h 20m' '8h' '16h 55m' '3h 10m' '14h' '23h 50m'
#  '21h 40m' '21h 15m' '10h 50m' '8h 15m' '8h 35m' '11h 50m' '27h 35m'
#  '8h 25m' '20h 55m' '4h 50m' '8h 10m' '24h 25m' '23h 35m' '25h 45m'
#  '26h 10m' '28h 50m' '25h 15m' '9h 20m' '9h 10m' '3h 5m' '11h 30m'
#  '9h 30m' '17h 35m' '5h 5m' '25h 50m' '20h' '13h' '18h 25m' '24h 10m'
#  '4h 55m' '25h 35m' '6h 20m' '18h 40m' '19h 25m' '29h 20m' '9h 5m'
#  '10h 45m' '11h 40m' '22h 55m' '37h 25m' '25h 40m' '13h 55m' '8h 40m'
#  '23h 30m' '12h 35m' '24h 15m' '1h 20m' '11h' '11h 15m' '14h 35m'
#  '12h 55m' '9h' '7h 40m' '11h 45m' '24h 55m' '17h 5m' '29h 55m' '22h 15m'
#  '14h 40m' '7h 15m' '20h 10m' '20h 45m' '27h' '24h 30m' '20h 25m' '5h 35m'
#  '14h 45m' '5h 40m' '4h 5m' '15h 55m' '7h 45m' '28h 20m' '4h 20m' '3h 40m'
#  '8h 50m' '23h 45m' '24h 45m' '21h 35m' '8h 5m' '6h 25m' '15h 50m'
#  '26h 25m' '24h 50m' '26h' '23h 5m' '7h 55m' '26h 20m' '23h 15m' '5h 20m'
#  '4h' '9h 45m' '8h 20m' '17h 25m' '7h 5m' '34h 5m' '6h 5m' '5h 50m' '7h'
#  '4h 25m' '13h 45m' '19h 15m' '22h 30m' '16h 25m' '13h 50m' '27h 5m'
#  '28h 10m' '4h 40m' '15h 40m' '4h 35m' '18h 30m' '38h 15m' '6h 35m'
#  '12h 30m' '11h 20m' '7h 35m' '29h 35m' '26h 55m' '23h 40m' '12h 50m'
#  '9h 50m' '21h 55m' '10h 55m' '21h 10m' '20h 40m' '30h' '13h 10m' '8h 45m'
#  '6h 10m' '17h 45m' '21h 45m' '3h 55m' '17h 20m' '30h 30m' '21h 25m'
#  '12h 40m' '24h 35m' '19h 10m' '22h 40m' '14h 55m' '21h' '6h 45m'
#  '28h 40m' '9h 40m' '16h 40m' '16h 20m' '16h 45m' '1h 15m' '6h 55m'
#  '11h 25m' '14h 20m' '12h 5m' '24h 5m' '28h 15m' '17h 50m' '20h 20m'
#  '28h 5m' '10h 20m' '14h 15m' '35h 15m' '35h 35m' '26h 40m' '28h'
#  '14h 25m' '13h 5m' '37h 20m' '36h 10m' '25h 55m' '35h 5m' '19h 45m'
#  '27h 55m' '47h' '10h 35m' '1h 35m' '16h 10m' '38h 20m' '6h' '16h 50m'
#  '14h 10m' '23h 20m' '17h 40m' '11h 35m' '18h 20m' '6h 40m' '30h 55m'
#  '24h 40m' '29h 50m' '28h 25m' '17h 15m' '22h 45m' '25h 25m' '21h 50m'
#  '33h 15m' '30h 15m' '3h 35m' '27h 40m' '30h 25m' '18h 50m' '27h 45m'
#  '15h 15m' '10h 40m' '26h 15m' '36h 25m' '26h 50m' '15h 45m' '19h 40m'
#  '22h 25m' '19h 35m' '25h' '26h 45m' '38h' '4h 15m' '25h 10m' '18h 15m'
#  '6h 50m' '23h 55m' '17h 55m' '23h 25m' '17h 10m' '24h 20m' '28h 30m'
#  '27h 10m' '19h 20m' '15h 35m' '9h 25m' '21h 30m' '34h 25m' '18h 35m'
#  '29h 40m' '26h 5m' '29h 5m' '27h 25m' '16h 30m' '11h 10m' '28h 55m'
#  '29h 10m' '34h' '30h 40m' '30h 45m' '32h 55m' '10h 5m' '35h 20m' '32h 5m'
#  '31h 40m' '19h 50m' '33h 45m' '30h 10m' '13h 40m' '19h 30m' '31h 30m'
#  '34h 30m' '27h 50m' '38h 35m' '42h 5m' '4h 10m' '39h 5m' '3h 50m' '5m'
#  '32h 30m' '31h 55m' '33h 20m' '27h 30m' '18h 55m' '9h 55m' '41h 20m'
#  '20h 5m' '31h 50m' '42h 45m' '3h 25m' '37h 10m' '29h 30m' '32h 20m'
#  '20h 50m' '40h 20m' '13h 35m' '47h 40m']
# Total Unique values are:  368
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Total_Stops
# ['non-stop' '2 stops' '1 stop' '3 stops' '4 stops']
# Total Unique values are:  5
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Unique Values in Additional_Info
# ['No info' 'In-flight meal not included' 'No check-in baggage included'
#  '1 Short layover' 'No Info' '1 Long layover' 'Change airports'
#  'Business class' 'Red-eye flight' '2 Long layover']
# Total Unique values are:  10
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  datetime64[ns]
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10682 non-null  object
#  6   Arrival_Time     10682 non-null  object
#  7   Duration         10682 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10682 non-null  object
#  10  Price            10682 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 1001.4+ KB

# %%
def change_hour_to_min(col):
    hour=df[col].str.replace("h","").str.replace("m","").str.split().str.get(0).astype('int')
    minute=df[col].str.replace("h","").str.replace("m","").str.split().str.get(1).astype("float").fillna(0)
    
    return (hour*60)+minute

# %%
df["Duration_In_Min"]=change_hour_to_min("Duration")

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Duration_In_Min
# 0            170.0
# 1            445.0
# 2           1140.0
# 3            325.0
# 4            285.0

# %%
df[['Duration_In_Min','Duration']]
# Out:
#        Duration_In_Min Duration
# 0                170.0   2h 50m
# 1                445.0   7h 25m
# 2               1140.0      19h
# 3                325.0   5h 25m
# 4                285.0   4h 45m
# ...                ...      ...
# 10678            150.0   2h 30m
# 10679            155.0   2h 35m
# 10680            180.0       3h
# 10681            160.0   2h 40m
# 10682            500.0   8h 20m
#
# [10682 rows x 2 columns]

# %%
df.sample(2)
# Out:
#           Airline Date_of_Journey    Source Destination            Route  \
# 6652       IndiGo      2019-05-21   Kolkata    Banglore  CCU → HYD → BLR
# 282   Jet Airways      2019-05-24  Banglore       Delhi        BLR → DEL
#
#      Dep_Time Arrival_Time Duration Total_Stops              Additional_Info  \
# 6652    15:15        20:05   4h 50m      1 stop                      No info
# 282     11:10        14:05   2h 55m    non-stop  In-flight meal not included
#
#       Price  Duration_In_Min
# 6652   5170            290.0
# 282    4030            175.0

# %%
df['Total_Stops']=df['Total_Stops'].str.extract(r"(\d+)").fillna(0).astype(int)

# %%
df.sample(3)
# Out:
#                 Airline Date_of_Journey   Source Destination  \
# 3849        Jet Airways      2019-05-27    Delhi      Cochin
# 4317  Multiple carriers      2019-05-18    Delhi      Cochin
# 7847        Jet Airways      2019-03-24  Kolkata    Banglore
#
#                       Route Dep_Time  Arrival_Time Duration  Total_Stops  \
# 3849  DEL → AMD → BOM → COK    19:10  19:00 28 May  23h 50m            2
# 4317        DEL → BOM → COK    08:30         19:15  10h 45m            1
# 7847        CCU → BOM → BLR    16:55  12:00 25 Mar   19h 5m            1
#
#      Additional_Info  Price  Duration_In_Min
# 3849         No info  15129           1430.0
# 4317         No info   7887            645.0
# 7847         No info  14231           1145.0

# %%
df['Additional_Info'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Additional_Info'>

# %%
df['Dep_hour']=pd.to_datetime(df['Dep_Time']).dt.hour
df['Dep_min']=pd.to_datetime(df['Dep_Time']).dt.minute

# %%
df['Arrival_hour']=pd.to_datetime(df['Arrival_Time']).dt.hour
df['Arrival_min']=pd.to_datetime(df['Arrival_Time']).dt.minute

# %%
df['Journey_year']=df['Date_of_Journey'].dt.year

# %%
df['Journey_month']=df['Date_of_Journey'].dt.month_name()
df['Journey_day']=df['Date_of_Journey'].dt.day_name()

# %%
df.head(1)
# Out:
#   Airline Date_of_Journey    Source Destination      Route Dep_Time  \
# 0  IndiGo      2019-03-24  Banglore   New Delhi  BLR → DEL    22:20
#
#    Arrival_Time Duration  Total_Stops Additional_Info  Price  Duration_In_Min  \
# 0  01:10 22 Mar   2h 50m            0         No info   3897            170.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year Journey_month  \
# 0        22       20             1           10          2019         March
#
#   Journey_day
# 0      Sunday

# %%
df.drop(columns=['Route','Duration','Additional_Info','Dep_Time','Arrival_Time','Date_of_Journey'],inplace=True)

# %%
df.head(1)
# Out:
#   Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 0  IndiGo  Banglore   New Delhi            0   3897            170.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year Journey_month  \
# 0        22       20             1           10          2019         March
#
#   Journey_day
# 0      Sunday

# %%
# Fun to plot graph
def fun_plot(col):
    v_count=df[col].value_counts()
    
    fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,7))
    ax1.set_title(f"Distrubution of {col}")
    sns.barplot(x=v_count.index,
               y=v_count.values,ax=ax1,palette='muted')
    
    ax1.set_xticklabels(ax1.get_xticklabels(), rotation='vertical')
    
    ax2.set_title(f"Pie Char of {col}")
    ax2.pie(v_count.values,labels=v_count.index,autopct="%.2f")
    plt.show()

# %%
airline=df['Airline'].value_counts()
airline
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df['Airline']=np.where(
    df['Airline']=='Vistara Premium economy','Vistara',
    np.where(df['Airline']=='Jet Airways Business','Jet Airways',
        df['Airline'])
)

# %%
airline=df['Airline'].value_counts()
airline
# Out:
# Airline
# Jet Airways                          3855
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               482
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Trujet                                  1
# Name: count, dtype: int64

# %%
fun_plot("Airline")

# %%
df['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
fun_plot('Source')

# %%
df['Destination'].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
fun_plot("Destination")

# %%
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1    5625
# 0    3491
# 2    1520
# 3      45
# 4       1
# Name: count, dtype: int64

# %%
fun_plot("Total_Stops")

# %%
df.head(1)
# Out:
#   Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 0  IndiGo  Banglore   New Delhi            0   3897            170.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year Journey_month  \
# 0        22       20             1           10          2019         March
#
#   Journey_day
# 0      Sunday

# %%
df=df[~(df['Total_Stops']==4)]

# %%
fun_plot("Total_Stops")

# %%
df.head(2)
# Out:
#      Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 0     IndiGo  Banglore   New Delhi            0   3897            170.0
# 1  Air India   Kolkata    Banglore            2   7662            445.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year Journey_month  \
# 0        22       20             1           10          2019         March
# 1         5       50            13           15          2019           May
#
#   Journey_day
# 0      Sunday
# 1   Wednesday

# %%
df['Journey_month'].value_counts()
# Out:
# Journey_month
# May      3465
# June     3414
# March    2723
# April    1079
# Name: count, dtype: int64

# %%
fun_plot('Journey_month')

# %%
df['Journey_day'].value_counts()
# Out:
# Journey_day
# Wednesday    2079
# Monday       1849
# Thursday     1832
# Saturday     1670
# Sunday       1474
# Friday        908
# Tuesday       869
# Name: count, dtype: int64

# %%
fun_plot("Journey_day")

# %%
def plot_numerical(col):
    fig,(ax1,ax2)=plt.subplots(1,2,figsize=(20,7))
    ax1.set_title(f"Distrubution of {col}")
    sns.histplot(df[col],ax=ax1)
    
    ax2.set_title(f"Distrubution of {col}")
    sns.distplot(df[col],ax=ax2)
    plt.show()

# %%
df['Price'].describe()
# Out:
# count    10681.000000
# mean      9086.409512
# std       4611.013975
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
plot_numerical("Price")

# %%
plt.title("Box plot of price")
sns.boxplot(df['Price'])
plt.show()

# %%
df[df['Price']>52000]
# Out:
#            Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 657    Jet Airways  Banglore   New Delhi            1  52229            300.0
# 1478   Jet Airways  Banglore   New Delhi            1  54826            365.0
# 2618   Jet Airways  Banglore   New Delhi            1  54826            375.0
# 2924   Jet Airways  Banglore   New Delhi            1  79512            340.0
# 5372   Jet Airways  Banglore   New Delhi            1  62427            400.0
# 5439   Jet Airways  Banglore   New Delhi            1  54826            365.0
# 9715   Jet Airways     Delhi      Cochin            2  52285            500.0
# 10364  Jet Airways  Banglore   New Delhi            1  57209            280.0
#
#        Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year  \
# 657           5       45            10           45          2019
# 1478         18       40             0           45          2019
# 2618         22       50             5            5          2019
# 2924          5       45            11           25          2019
# 5372          5       45            12           25          2019
# 5439         16       55            23            0          2019
# 9715         20        5             4           25          2019
# 10364         9       45            14           25          2019
#
#       Journey_month Journey_day
# 657           March      Friday
# 1478          March      Monday
# 2618          March      Monday
# 2924          March      Friday
# 5372          March      Friday
# 5439          March      Friday
# 9715          March   Wednesday
# 10364         March      Friday

# %%
df=df[~(df['Price']>60000)]

# %%
df['Duration_In_Min'].describe()
# Out:
# count    10679.000000
# mean       642.993726
# std        507.743756
# min         75.000000
# 25%        170.000000
# 50%        520.000000
# 75%        930.000000
# max       2860.000000
# Name: Duration_In_Min, dtype: float64

# %%
plot_numerical("Duration_In_Min")

# %%
plt.title("Box plot of Duration in min")
sns.boxplot(df['Duration_In_Min'])
plt.show()

# %%
df[df['Duration_In_Min']>2000].sample(10)
# Out:
#           Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 7626  Jet Airways     Delhi      Cochin            2  20747           2045.0
# 7189    Air India    Mumbai   Hyderabad            2  12119           2245.0
# 5061  Jet Airways     Delhi      Cochin            2  15812           2070.0
# 2718    Air India     Delhi      Cochin            3  15586           2280.0
# 4785    Air India  Banglore   New Delhi            2  11948           2105.0
# 8127    Air India     Delhi      Cochin            2   9968           2295.0
# 6321    Air India  Banglore   New Delhi            2  17135           2345.0
# 5711    Air India    Mumbai   Hyderabad            2  13904           2245.0
# 5953  Jet Airways     Delhi      Cochin            2  11664           2525.0
# 2641    Air India     Delhi      Cochin            2   7711           2240.0
#
#       Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year  \
# 7626        18       20             4           25          2019
# 7189         6        0            19           25          2019
# 5061        17       55             4           25          2019
# 2718         5       15            19           15          2019
# 4785        11        5            22           10          2019
# 8127         5        0            19           15          2019
# 6321         8       50            23           55          2019
# 5711         6        0            19           25          2019
# 5953        10       20             4           25          2019
# 2641         5       55            19           15          2019
#
#      Journey_month Journey_day
# 7626         March      Sunday
# 7189         March     Tuesday
# 5061         March   Wednesday
# 2718         March    Saturday
# 4785         March      Sunday
# 8127          June      Sunday
# 6321         March      Friday
# 5711         March   Wednesday
# 5953         March    Thursday
# 2641         April     Tuesday

# %%
plt.figure(figsize=(15,7))
plt.title("Relationship b/w price and duration in minute")
sns.scatterplot(x=df['Duration_In_Min'],
               y=df['Price'])
plt.show()

# %%
df.head(1)
# Out:
#   Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 0  IndiGo  Banglore   New Delhi            0   3897            170.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year Journey_month  \
# 0        22       20             1           10          2019         March
#
#   Journey_day
# 0      Sunday

# %%
plt.figure(figsize=(15,7))
plt.title("Relationship b/w price and Journey Month")
sns.lineplot(x=df['Journey_month'],
               y=df['Price'])
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Relationship b/w price and Journey Day")
sns.lineplot(x=df['Journey_day'],
               y=df['Price'])
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Relationship b/w price and Journey Day")
sns.lineplot(x=df['Journey_day'],
               y=df['Price'],hue=df['Journey_month'])

plt.show()

# %%
temp=df.groupby(['Journey_month','Journey_day'])['Price'].mean().reset_index().sort_values(by='Journey_day',ascending=True)
temp.head()
# Out:
#    Journey_month Journey_day         Price
# 0          April      Friday   5124.031746
# 21           May      Friday   7794.789894
# 14         March      Friday  13633.379888
# 7           June      Friday   4950.724771
# 1          April      Monday   6850.841040

# %%
plt.figure(figsize=(15,7))
plt.title(f"Avg price in each month and day")
sns.barplot(x=temp['Journey_month'],
               y=temp['Price'],hue=temp['Journey_day'],palette='pastel')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Relationship b/w price and Dep_hour")
sns.lineplot(x=df['Dep_hour'],
               y=df['Price'])
plt.show()

# %%
air_price=df.groupby(['Airline'])['Price'].mean().reset_index()
air_price
# Out:
#                              Airline         Price
# 0                           Air Asia   5590.260188
# 1                          Air India   9607.814286
# 2                              GoAir   5861.056701
# 3                             IndiGo   5673.682903
# 4                        Jet Airways  11685.874384
# 5                  Multiple carriers  10902.678094
# 6  Multiple carriers Premium economy  11418.846154
# 7                           SpiceJet   4338.284841
# 8                             Trujet   4140.000000
# 9                            Vistara   7803.605809

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,7))
ax1.set_title(f"Price Of each airline")
sns.barplot(x=air_price['Airline'],
               y=air_price['Price'],ax=ax1,palette='muted')
    
ax1.set_xticklabels(ax1.get_xticklabels(), rotation='vertical')
    
ax2.set_title(f"Price of each airline")
ax2.pie(air_price['Price'],labels=air_price['Airline'],autopct="%.2f")
plt.show()

# %%
source=df.groupby(['Source'])['Price'].mean().reset_index()
source
# Out:
#      Source         Price
# 0  Banglore   7955.671832
# 1   Chennai   4789.892388
# 2     Delhi  10540.113536
# 3   Kolkata   9158.389411
# 4    Mumbai   5059.708752

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,7))
ax1.set_title(f"Price from source")
sns.barplot(x=source['Source'],
               y=source['Price'],ax=ax1,palette='muted')
    
ax1.set_xticklabels(ax1.get_xticklabels(), rotation='vertical')
    
ax2.set_title(f"Price from source")
ax2.pie(source['Price'],labels=source['Source'],autopct="%.2f")
plt.show()

# %%
destination=df.groupby(['Destination'])['Price'].mean().reset_index()
destination
# Out:
#   Destination         Price
# 0    Banglore   9158.389411
# 1      Cochin  10540.113536
# 2       Delhi   5143.918577
# 3   Hyderabad   5059.708752
# 4     Kolkata   4789.892388
# 5   New Delhi  11784.377826

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,7))
ax1.set_title(f"Price to destination")
sns.barplot(x=destination['Destination'],
               y=destination['Price'],ax=ax1,palette='muted')
    
ax1.set_xticklabels(ax1.get_xticklabels(), rotation='vertical')
    
ax2.set_title(f"Price to destination")
ax2.pie(destination['Price'],labels=destination['Destination'],autopct="%.2f")
plt.show()

# %%
df.head(2)
# Out:
#      Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 0     IndiGo  Banglore   New Delhi            0   3897            170.0
# 1  Air India   Kolkata    Banglore            2   7662            445.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year Journey_month  \
# 0        22       20             1           10          2019         March
# 1         5       50            13           15          2019           May
#
#   Journey_day
# 0      Sunday
# 1   Wednesday

# %%
stops=df.groupby(['Total_Stops'])['Price'].mean().reset_index()
stops
# Out:
#    Total_Stops         Price
# 0            0   5024.900315
# 1            1  10572.649120
# 2            2  12715.807895
# 3            3  13112.000000

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,7))
ax1.set_title(f"Price and total stops")
sns.barplot(x=stops['Total_Stops'],
               y=stops['Price'],ax=ax1,palette='muted')
    
ax1.set_xticklabels(ax1.get_xticklabels(), rotation='vertical')
    
ax2.set_title(f"Price and total stops")
ax2.pie(stops['Price'],labels=stops['Total_Stops'],autopct="%.2f")
plt.show()

# %%
df.head(2)
# Out:
#      Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 0     IndiGo  Banglore   New Delhi            0   3897            170.0
# 1  Air India   Kolkata    Banglore            2   7662            445.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min  Journey_year Journey_month  \
# 0        22       20             1           10          2019         March
# 1         5       50            13           15          2019           May
#
#   Journey_day
# 0      Sunday
# 1   Wednesday

# %%
df.select_dtypes('number').corr()['Price']
# Out:
# Total_Stops        0.613790
# Price              1.000000
# Duration_In_Min    0.516762
# Dep_hour           0.010488
# Dep_min           -0.027948
# Arrival_hour       0.025452
# Arrival_min       -0.087688
# Journey_year            NaN
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(15,7))
plt.title("Correlation Matrix")
sns.heatmap(df.select_dtypes('number').corr(),annot=True)
plt.show()

# %%
df.drop(columns=['Journey_year'],inplace=True)

# %%
df.head(1)
# Out:
#   Airline    Source Destination  Total_Stops  Price  Duration_In_Min  \
# 0  IndiGo  Banglore   New Delhi            0   3897            170.0
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min Journey_month Journey_day
# 0        22       20             1           10         March      Sunday

# %%
df.to_csv("flight_clean.csv")

# %%
from sklearn.model_selection import train_test_split,cross_val_score

# %%
feature=df.drop(columns=['Price'])
label=df['Price']

# %%
feature.head(1)
# Out:
#   Airline    Source Destination  Total_Stops  Duration_In_Min  Dep_hour  \
# 0  IndiGo  Banglore   New Delhi            0            170.0        22
#
#    Dep_min  Arrival_hour  Arrival_min Journey_month Journey_day
# 0       20             1           10         March      Sunday

# %%
label.head(2)
# Out:
# 0    3897
# 1    7662
# Name: Price, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(feature,label,test_size=0.2,random_state=43)

# %%
x_train.shape
# Out:
# (8543, 11)

# %%
x_test.shape
# Out:
# (2136, 11)

# %%
y_train.shape
# Out:
# (8543,)

# %%
y_test.shape
# Out:
# (2136,)

# %%
num_col=feature.select_dtypes('number').columns
num_col
# Out:
# Index(['Total_Stops', 'Duration_In_Min', 'Dep_hour', 'Dep_min', 'Arrival_hour',
#        'Arrival_min'],
#       dtype='object')

# %%
cat_col=feature.select_dtypes("object").columns
cat_col
# Out:
# Index(['Airline', 'Source', 'Destination', 'Journey_month', 'Journey_day'], dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder,FunctionTransformer
from sklearn.impute import SimpleImputer

# %%
num_pipe=Pipeline(steps=[
    ("Impute",SimpleImputer(strategy='median')),
    ("scale",StandardScaler()),
])
num_pipe
# Out:
# Pipeline(steps=[('Impute', SimpleImputer(strategy='median')),
#                 ('scale', StandardScaler())])

# %%
cat_pipe=Pipeline(steps=[
    ("inpute",SimpleImputer(strategy="most_frequent")),
    ('encode',OneHotEncoder(sparse_output=False,handle_unknown='ignore',drop='first'))
])
cat_pipe
# Out:
# Pipeline(steps=[('inpute', SimpleImputer(strategy='most_frequent')),
#                 ('encode',
#                  OneHotEncoder(drop='first', handle_unknown='ignore',
#                                sparse_output=False))])

# %%
trasform=ColumnTransformer(transformers=[
    ("num_trans",num_pipe,num_col),
    ("cat_trans",cat_pipe,cat_col)
],remainder='passthrough')
trasform
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('num_trans',
#                                  Pipeline(steps=[('Impute',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scale', StandardScaler())]),
#                                  Index(['Total_Stops', 'Duration_In_Min', 'Dep_hour', 'Dep_min', 'Arrival_hour',
#        'Arrival_min'],
#       dtype='object')),
#                                 ('cat_trans',
#                                  Pipeline(steps=[('inpute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['Airline', 'Source', 'Destination', 'Journey_month', 'Journey_day'], dtype='object'))])

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
final=Pipeline(steps=[
    ("Process",trasform),
    ("model",RandomForestRegressor())
])
final
# Out:
# Pipeline(steps=[('Process',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num_trans',
#                                                   Pipeline(steps=[('Impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   Index(['Total_Stops', 'Duration_In_Min', 'Dep_hour', 'Dep_min', 'Arrival_hour',
#        'Arrival_min'],
#       dtype='object')),
#                                                  ('cat_trans',
#                                                   Pipeline(steps=[('inpute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encode',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   Index(['Airline', 'Source', 'Destination', 'Journey_month', 'Journey_day'], dtype='object'))])),
#                 ('model', RandomForestRegressor())])

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
def evulation(actual,pre,n,k):
    r2=r2_score(actual,pre)
    return {
        "Mean Square Error":mean_squared_error(actual,pre),
        "Mean Absoulute Error":mean_absolute_error(actual,pre),
        "R2_Score":r2,
        "Adjusted R2_score":1 - ((1 - r2) * (n - 1)) / (n - k - 1)
    }

# %%
models={
    "LinearRegression":LinearRegression(),
    "Ridge":Ridge(alpha=0.001),
    "Lasso":Lasso(alpha=0.001),
    "RandomForest":RandomForestRegressor(),
    "AdaBoost":AdaBoostRegressor(),
    "xgboost":XGBRegressor(),
    "Gradiant Boost":GradientBoostingRegressor(learning_rate=0.001)
}

# %%
results={
    "model":[],
    "r2_score":[],
    "mean_squared_error":[],
    "mean_absolute_error":[],
    "adjusted":[],
    "train score":[],
    "test_score":[],
}
for model_name,model in models.items():  
    print("Model ",model_name)
    
    final=Pipeline(steps=[
    ("Process",trasform),
    ("model",model)
    ])
    
    print("Fit the model")
    final.fit(x_train,y_train)
    
    # prediction
    print("Prediction")
    y_pred=final.predict(x_test)
    
    # Evulation
    print("Evulation")
    r2=r2_score(y_test,y_pred)
    results["r2_score"].append(r2)
    results["mean_squared_error"].append(mean_squared_error(y_test,y_pred))
    results["mean_absolute_error"].append(mean_absolute_error(y_test,y_pred))
    adjust=1 - ((1 - r2) * (x_train.shape[0] - 1)) / (x_train.shape[0] - x_train.shape[1] - 1)
    
    results["adjusted"].append(adjust)

        # Train score
    print("Train Cross validation")
    train_score=np.round(cross_val_score(final,x_train,y_train,cv=5,scoring='r2').mean(),3)
    
    # test score
    print("Test Cross validation")
    test_score=np.round(cross_val_score(final,x_test,y_test,cv=5,scoring='r2').mean(),3)
    
    results['model'].append(model_name)
    
    results['train score'].append(train_score)
    
    results['test_score'].append(test_score)
    
    # Visulize the result
    plt.figure(figsize=(10,7))
    plt.title(f"Performacen of model {model_name}")
    sns.regplot(x=y_test,y=y_pred,color='blue')
    plt.xlabel("Actual ")
    plt.ylabel("predicted")
    plt.show()
# Out:
# Model  LinearRegression
# Fit the model
# Prediction
# Evulation
# Train Cross validation
# Test Cross validation
# Model  Ridge
# Fit the model
# Prediction
# Evulation
# Train Cross validation
# Test Cross validation
# Model  Lasso
# Fit the model
# Prediction
# Evulation
# Train Cross validation
# Test Cross validation
# Model  RandomForest
# Fit the model
# Prediction
# Evulation
# Train Cross validation

# %%
pd.DataFrame(results)
